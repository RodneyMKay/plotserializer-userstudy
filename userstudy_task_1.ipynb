# %% [markdown]
# # Task 1
#
# Please serialize the given plot below and write the serialized plot into the userstudy.json file.
#
# > You can find the Plotserializer documentation [here](https://mt.gg/temp_plotserializer_docs/).
#
# > TIP : open the file userstudy.json in a diffrent window so you can simply refresh the window and see your changes

# %%
import matplotlib.pyplot as plt

labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
ax.set_title("My amazing Pie Plot")

# please note that the .show() methode dose not function when used like serializer.show() and you still have to use plt.show()
plt.show()
