# %%
# task 2.1:
#   please serialize the given bar plot

import matplotlib.pyplot as plt

names = ["a", "b", "c", "d", "e", "f", "g", "h"]
heights = [1, 2, 10, 100, 150, 1000, 1500, 10000]
color = ["red", "green", "blue", "orange", "purple", "cyan", "blue", "blue"]

_, ax = plt.subplots()
ax.bar(names, heights, color=color)
ax.set_title("My amazing bar plot")

ax.set_yscale("log")
ax.set_ylabel("log axis")

plt.show()

# %%
# task 2.2:
#   please serialize the given scatter plot

import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 3]
y = [2, 1.5, 5, 0, 4]
color = ["red", "green", "blue", "orange", "cyan"]
sizes = [1, 50, 100, 200, 300]

_, ax = plt.subplots()
ax.scatter(x, y, c=color, s=sizes)

plt.show()

# %%
# task 2.3:
#   please serialize the given line plot
#   the plot is much more complex, can you make out the data for the red line inside the JSON file?

import matplotlib.pyplot as plt
import numpy as np

def func(x, d: float):
    return 1 / (np.sqrt((1 - x**2) ** 2 + (2 * x * d)))

x = np.linspace(0, 3, 500)

e = func(x, 0)
y = func(x, 0.1)
y2 = func(x, 0.2)
y3 = func(x, 0.5)
y4 = func(x, 1)

_, ax = plt.subplots()
ax.plot(x, e, label="Einhüllend", linestyle="--", color="gray")
ax.plot(x, y, label="D = 0.1")
ax.plot(x, y2, label="D = 0.2")
ax.plot(x, y3, label="D = 0.5")
ax.plot(x, y4, label="D = 1")

ax.legend()
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
ax.set_xlabel(r"$\omega/\omega_0$")
ax.set_ylabel("$A/A_E$")
ax.grid(True)
ax.set_title("Ressonanz")

plt.show()
