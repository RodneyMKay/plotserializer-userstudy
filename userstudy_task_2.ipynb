# %% [markdown]
# # Task 2.1
#
# Please serialize the given bar plot.
#
# Please try to add some **Metadata** you see fit, like your name and the date.
#
# > The other tasks are below
#
# > You can find the Plotserializer documentation [here](https://mt.gg/temp_plotserializer_docs/).

# %%
import matplotlib.pyplot as plt

names = ["a", "b", "c", "d", "e", "f", "g", "h"]
heights = [1, 2, 10, 100, 150, 1000, 1500, 10000]
color = ["red", "green", "blue", "orange", "purple", "cyan", "blue", "blue"]

_, ax = plt.subplots()
ax.bar(names, heights, color=color)
ax.set_title("My amazing bar plot")

ax.set_xlabel("some kind of bars")
ax.set_yscale("log")
ax.set_ylabel("log axis")

plt.show()

# %% [markdown]
# # Task 2.2
# Please serialize the given line plot
#
# Now the plot is much more complex, can you make out the data for the red line inside the JSON file?
# You can also try to read only the red line from the JSON file and print it.

# %%
import matplotlib.pyplot as plt
import numpy as np

def func(x, d: float):
    return 1 / (np.sqrt((1 - x**2) ** 2 + (2 * x * d)))

x = np.linspace(0, 3, 500)

e = func(x, 0)
y = func(x, 0.1)
y2 = func(x, 0.2)
y3 = func(x, 0.5)
y4 = func(x, 1)

_, ax = plt.subplots()
ax.plot(x, e, label="Einhüllend", linestyle="--", color="gray")
ax.plot(x, y, label="D = 0.1")
ax.plot(x, y2, label="D = 0.2")
ax.plot(x, y3, label="D = 0.5")
ax.plot(x, y4, label="D = 1")

ax.legend()
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
ax.set_xlabel(r"$\omega/\omega_0$")
ax.set_ylabel("$A/A_E$")
ax.grid(True)
ax.set_title("Ressonanz")

plt.show()
